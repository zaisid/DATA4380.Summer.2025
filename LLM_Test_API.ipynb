# %%
import os

# %%
#!pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.27.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 2.8 MB/s eta 0:00:00
# Collecting anyio<5.0.0,>=4.8.0 (from google-genai)
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-genai)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai) (2.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai) (2.32.2)
# Collecting tenacity<9.0.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.4.8)
# Downloading google_genai-1.27.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.5/218.5 kB 11.8 MB/s eta 0:00:00
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 18.6 MB/s eta 0:00:00
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 19.0 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 8.2 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Installing collected packages: tenacity, rsa, anyio, httpx, google-auth, google-genai
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.26.0
#     Uninstalling httpx-0.26.0:
#       Successfully uninstalled httpx-0.26.0
# Successfully installed anyio-4.9.0 google-auth-2.40.3 google-genai-1.27.0 httpx-0.28.1 rsa-4.9.1 tenacity-8.5.0

# %%
from google import genai
from PIL import Image
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pydantic/_internal/_fields.py:184: UserWarning: Field name "name" shadows an attribute in parent "Operation";
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pydantic/_internal/_fields.py:184: UserWarning: Field name "metadata" shadows an attribute in parent "Operation";
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pydantic/_internal/_fields.py:184: UserWarning: Field name "done" shadows an attribute in parent "Operation";
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/pydantic/_internal/_fields.py:184: UserWarning: Field name "error" shadows an attribute in parent "Operation";
#   warnings.warn(

# %%
model="gemma-3-27b-it"

# %%
img_path = "/Users/zainabsiddiqui/Downloads/Data_Problems/LLM_Project/Data/test.png"

# %%
REQUEST = "Identify and count the shapes in this image"

# %%
client = genai.Client()

image = Image.open(img_path)

response = client.models.generate_content(
  model=model,
  contents=[image, REQUEST],
  )

print(response.text) # The output often is markdown
# Out:
# Here's a breakdown of the shapes in the image:
#
# *   **Circles:** There are 3 circles (blue, yellow, and turquoise).
# *   **Rectangle:** There is 1 rectangle (gray).
#
# **Total:** 4 shapes.

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=926x914>

# %% [markdown]
#     Answer was exactly correct. Too easy?
